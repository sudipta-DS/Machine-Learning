# %%
print("HellO wORLD")
# Out:
# HellO wORLD

# %%
# YOU ARE AN AWESOM GUY

# %% [markdown]
# ## This is  sudipta here
# ### I know languages

# %%
# String  operations 

str1 = "Hello World"
print(str1)
type(str1)
# Out:
# Hello World
# str

# %%
a= 'z'
type(a)
# Out:
# str

# %%
a = ('%0.3f'%(10/20))

# %%
type(a)
# Out:
# str

# %%
a = (10/20)

# %%
a
# Out:
# 0.5

# %%
x= 7
b=(a+x)

# %%
b
# Out:
# 7.5
