# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_samples=1000,n_features=1,n_targets=1,noise=10)

# %%
x.shape,y.shape
# Out:
# ((1000, 1), (1000,))

# %%
plt.scatter(x,y,s=5)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([52.04919496])

# %%
lr.intercept_
# Out:
# 0.03797612049478716

# %%
pred = lr.predict(x)

# %%
plt.scatter(x,y,label='points')
plt.xlabel("Feature-X")
plt.ylabel("Traget-Y")
plt.plot(x,pred,color="orange",label='regressionLine')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=.1)
lr.fit(x,y)
ridge.fit(x,y)
# Out:
# Ridge(alpha=0.1)

# %%
print(ridge.coef_,lr.coef_)
# Out:
# [52.04416514] [52.04919496]

# %%
print(ridge.intercept_,lr.intercept_)
# Out:
# 0.03800353596874906 0.03797612049478716

# %%
outliers = y[950:]-600

# %%
import numpy as np
y_out = np.append(y[:950],outliers)

# %%
plt.scatter(x,y_out)

# %%
plt.scatter(x,y_out)
plt.plot(x,pred,color='red',label='Line Without Outliers')
plt.plot(x,pred_out,color='green',label='Line With Outliers')
plt.legend()
plt.show()

# %%
lr.fit(x,y_out)
# Out:
# LinearRegression()

# %%
pred_out = lr.predict(x)

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso(alpha=100)

# %%
ls.fit(x,y_out)
# Out:
# Lasso(alpha=100)

# %%
pred_lasso = ls.predict(x)

# %%
plt.scatter(x,y_out)
plt.plot(x,pred,color='red',label='Line With Linear Regression')
plt.plot(x,pred_lasso,color='green',label='Line With Lasso Regularization')
plt.legend()
plt.show()

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge(alpha=1000)

# %%
ridge.fit(x,y_out)
# Out:
# Ridge(alpha=1000)

# %%
pred_ridge = ridge.predict(x)

# %%
plt.scatter(x,y_out)
plt.plot(x,pred,color='red',label='Line With Linear Regression')
plt.plot(x,pred_ridge,color='green',label='Line With Ridge Regularization')
plt.legend()
plt.show()

# %% [markdown]
# ### Elastic Net

# %%
from sklearn.linear_model import ElasticNet

# %%
en = ElasticNet()

# %%
en.fit(x,y_out)
# Out:
# ElasticNet()

# %%
pred_en = en.predict(x)

# %%
plt.scatter(x,y_out)
plt.plot(x,pred,color='red',label='Line With Linear Regression')
plt.plot(x,pred_en,color='green',label='Line With ElasticNet Regression')
plt.legend()
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.datasets import make_blobs

# %%
x,y = make_blobs(n_samples=1000,n_features=2,centers=2,cluster_std=2.0)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
from sklearn.linear_model import LogisticRegression
logistic= LogisticRegression()
logistic.fit(x,y)
# Out:
# LogisticRegression()

# %%
pred_logistic = logistic.predict(x[:20,:])

# %%
logistic.score(x,y)
# Out:
# 1.0

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.plot(x[:20,1],pred_logistic)

# %% [markdown]
# ### Polynomial Regression

# %%
m = 100
x = 6*np.random.rand(m,1)-3
y = 0.5*(x**2)+ x + 2 + np.random.randn(m,1)

# %%
x.shape
# Out:
# (100, 1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2,include_bias=False)

x_poly = poly.fit_transform(x)

# %%
plt.scatter(x_poly[:,0],x_poly[:,1])

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_poly,y)
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([2.15129147]), array([[0.97116837, 0.46450787]]))

# %%
pred = lin_reg.predict(x_poly[80:,:])

# %%
pred.shape
# Out:
# (20, 1)

# %%
x_poly.shape
# Out:
# (100, 2)
